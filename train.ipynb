# %%
import pandas as pd

# %%
df = pd.read_csv("drop_data.csv")
df
# Out:
#            id diagnosis  texture_mean  area_mean  smoothness_mean  \
# 0      842302         M         10.38     1001.0          0.11840
# 1      842517         M         17.77     1326.0          0.08474
# 2    84300903         M         21.25     1203.0          0.10960
# 3    84348301         M         20.38      386.1          0.14250
# 4    84358402         M         14.34     1297.0          0.10030
# ..        ...       ...           ...        ...              ...
# 564    926424         M         22.39     1479.0          0.11100
# 565    926682         M         28.25     1261.0          0.09780
# 566    926954         M         28.08      858.1          0.08455
# 567    927241         M         29.33     1265.0          0.11780
# 568     92751         B         24.54      181.0          0.05263
#
#      concavity_mean  symmetry_mean  fractal_dimension_mean  texture_se  \
# 0           0.30010         0.2419                 0.07871      0.9053
# 1           0.08690         0.1812                 0.05667      0.7339
# 2           0.19740         0.2069                 0.05999      0.7869
# 3           0.24140         0.2597                 0.09744      1.1560
# 4           0.19800         0.1809                 0.05883      0.7813
# ..              ...            ...                     ...         ...
# 564         0.24390         0.1726                 0.05623      1.2560
# 565         0.14400         0.1752                 0.05533      2.4630
# 566         0.09251         0.1590                 0.05648      1.0750
# 567         0.35140         0.2397                 0.07016      1.5950
# 568         0.00000         0.1587                 0.05884      1.4280
#
#      area_se  smoothness_se  concavity_se  symmetry_se  fractal_dimension_se  \
# 0     153.40       0.006399       0.05373      0.03003              0.006193
# 1      74.08       0.005225       0.01860      0.01389              0.003532
# 2      94.03       0.006150       0.03832      0.02250              0.004571
# 3      27.23       0.009110       0.05661      0.05963              0.009208
# 4      94.44       0.011490       0.05688      0.01756              0.005115
# ..       ...            ...           ...          ...                   ...
# 564   158.70       0.010300       0.05198      0.01114              0.004239
# 565    99.04       0.005769       0.03950      0.01898              0.002498
# 566    48.55       0.005903       0.04730      0.01318              0.003892
# 567    86.22       0.006522       0.07117      0.02324              0.006185
# 568    19.15       0.007189       0.00000      0.02676              0.002783
#
#      smoothness_worst  concavity_worst  symmetry_worst  \
# 0             0.16220           0.7119          0.4601
# 1             0.12380           0.2416          0.2750
# 2             0.14440           0.4504          0.3613
# 3             0.20980           0.6869          0.6638
# 4             0.13740           0.4000          0.2364
# ..                ...              ...             ...
# 564           0.14100           0.4107          0.2060
# 565           0.11660           0.3215          0.2572
# 566           0.11390           0.3403          0.2218
# 567           0.16500           0.9387          0.4087
# 568           0.08996           0.0000          0.2871
#
#      fractal_dimension_worst
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 18 columns]

# %%
from sklearn.model_selection import train_test_split

# splitting data
X_train, X_test, y_train, y_test = train_test_split(
                df.drop('diagnosis', axis=1),
                df['diagnosis'],
                test_size=0.2,
                random_state=42)

print("Shape of training set:", X_train.shape)
print("Shape of test set:", X_test.shape)
# Out:
# Shape of training set: (455, 17)
# Shape of test set: (114, 17)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.fit_transform(X_test)

# %%
# SVC
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

svc_model = SVC(kernel="rbf")
svc_model.fit(X_train, y_train)
predictions5 = svc_model.predict(X_test)

print("Confusion Matrix: \n", confusion_matrix(y_test, predictions5))
print("\n")
print(classification_report(y_test, predictions5))

svm_acc = accuracy_score(y_test, predictions5)
print("Accuracy of SVM model is: ", svm_acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 9
#       6 svc_model.fit(X_train, y_train)
#       7 predictions5 = svc_model.predict(X_test)
# ----> 9 print("Confusion Matrix: \n", confusion_matrix(y_test, predictions5))
#      10 print("\n")
#      11 print(classification_report(y_test, predictions5))
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
predictions1 = logreg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

print("Confusion Matrix: \n", confusion_matrix(y_test, predictions1))
print('\n')
print(classification_report(y_test, predictions1))

# %%
from sklearn.metrics import accuracy_score

logreg_acc = accuracy_score(y_test, predictions1)
print("Accuracy of the Logistic Regression Model is: ", logreg_acc)

# %% [markdown]
# # Try all column

# %%
ori_df = pd.read_csv('raw_data/data.csv')
ori_df.info()

# %%
ori_df = ori_df.drop(labels='Unnamed: 32', axis=1)
ori_df.head()

# %%
from sklearn.model_selection import train_test_split

# splitting data
X_train, X_test, y_train, y_test = train_test_split(
                ori_df.drop('diagnosis', axis=1),
                ori_df['diagnosis'],
                test_size=0.2,
                random_state=42)

print("Shape of training set:", X_train.shape)
print("Shape of test set:", X_test.shape)

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(X_train, y_train)
predictions1 = logreg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

print("Confusion Matrix: \n", confusion_matrix(y_test, predictions1))
print('\n')
print(classification_report(y_test, predictions1))

# %%
from sklearn.metrics import accuracy_score

logreg_acc = accuracy_score(y_test, predictions1)
print("Accuracy of the Logistic Regression Model is: ", logreg_acc)

# %% [markdown]
# # Support Vector Machines (SVM) - ori data

# %%
from sklearn.svm import SVC

svc_model = SVC(kernel="rbf")
svc_model.fit(X_train, y_train)
predictions5 = svc_model.predict(X_test)

# %%
print("Confusion Matrix: \n", confusion_matrix(y_test, predictions5))
print("\n")
print(classification_report(y_test, predictions5))

# %%
svm_acc = accuracy_score(y_test, predictions5)
print("Accuracy of SVM model is: ", svm_acc)
